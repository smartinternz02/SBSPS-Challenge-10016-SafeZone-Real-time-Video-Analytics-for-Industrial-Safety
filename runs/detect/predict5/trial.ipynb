# %%
pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sarth\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sarth\appdata\local\programs\python\python39\lib\site-packages)

# %%
import numpy as np
import pandas as pd
import warnings
import matplotlib.pyplot as plt
from IPython.core.magic import register_line_cell_magic
import yaml
from PIL import Image
import os
import seaborn as sns
from ultralytics import YOLO
from matplotlib.patches import Rectangle
import glob
import cv2

# %%
warnings.filterwarnings("ignore")

np.random.seed(12345)

# %matplotlib inline

# !wandb disabled
# Out:
# W&B disabled.

# %%
pip install wandb
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sarth\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sarth\appdata\local\programs\python\python39\lib\site-packages)

# %%
warnings.filterwarnings("ignore")

np.random.seed(12345)

# %matplotlib inline

# !wandb disabled
# Out:
# W&B disabled.

# %%
Input_path = '/kaggle/input/construction-site-safety-image-dataset-roboflow/css-data'
Work_path = '/kaggle/working/'

# %%
num_classes = 10
classes = ['Hardhat', 'Mask', 'NO-Hardhat', 'NO-Mask', 'NO-Safety Vest', 'Person', 'Safety Cone', 'Safety Vest', 'machinery', 'vehicle']

# %%
dict_file = {'train': os.path.join(Input_path, 'train'),
             'val': os.path.join(Input_path, 'valid'),
             'test': os.path.join(Input_path, 'test'),
             'nc': num_classes,
             'names': classes
            }

with open(os.path.join(Work_path, 'data.yaml'), 'w+') as file:
    yaml.dump(dict_file, file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 8
#       1 dict_file = {'train': os.path.join(Input_path, 'train'),
#       2              'val': os.path.join(Input_path, 'valid'),
#       3              'test': os.path.join(Input_path, 'test'),
#       4              'nc': num_classes,
#       5              'names': classes
#       6             }
# ----> 8 with open(os.path.join(Work_path, 'data.yaml'), 'w+') as file:
#       9     yaml.dump(dict_file, file)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
# ...

# %%
model = YOLO('C:\\ipynb_yolov5\\results_yolov8n_100e\\kaggle\\working\\runs\\detect\\train\\weights\\best.pt')

# %%
results = model.predict(source='C:\\Users\\sarth\\Downloads\\Safety Gear Detection.v1i.yolov5pytorch\\test\\images\\set01hjimg2399_jpg.rf.8cdd7079a025bddb06c54f6e4de335b0.jpg', save=True)
# Out:
# image 1/1 C:\Users\sarth\Downloads\Safety Gear Detection.v1i.yolov5pytorch\test\images\set01hjimg2399_jpg.rf.8cdd7079a025bddb06c54f6e4de335b0.jpg: 640x640 1 Hardhat, 1 NO-Mask, 1 Person, 1 Safety Vest, 327.8ms
# Speed: 8.0ms preprocess, 327.8ms inference, 24.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict3

# %%
results = model.predict(source='C:\\Users\\sarth\\Downloads\\Safety Gear Detection.v1i.yolov5pytorch\\test\images\\set01hjimg218_jpg.rf.20a5b4bc83f18dc0509f9aa972bf49de.jpg', save=True)
# Out:
# image 1/1 C:\Users\sarth\Downloads\Safety Gear Detection.v1i.yolov5pytorch\test\images\set01hjimg218_jpg.rf.20a5b4bc83f18dc0509f9aa972bf49de.jpg: 640x640 2 Hardhats, 2 NO-Masks, 1 NO-Safety Vest, 4 Persons, 2 Safety Vests, 247.8ms
# Speed: 8.0ms preprocess, 247.8ms inference, 8.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict3

# %%
import cv2


# Load the model
model = YOLO('C:\\ipynb_yolov5\\results_yolov8n_100e\\kaggle\\working\\runs\\detect\\train\\weights\\best.pt')

# Initialize the camera
camera = cv2.VideoCapture(0)  # 0 indicates the default camera (usually the built-in laptop camera)

while True:
    # Capture a frame from the camera
    ret, frame = camera.read()

    if not ret:
        print("Failed to capture frame from camera.")
        break

    # Perform any necessary preprocessing on the frame here

    # Save the frame as a temporary image file
    cv2.imwrite('temp_frame.jpg', frame)

    # Predict using the model
    results = model.predict(source='temp_frame.jpg', save=True)

    # Display the results or take any necessary actions
    # ...

    # Exit the loop if a key is pressed (e.g., 'q')
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the camera and close any windows
camera.release()
cv2.destroyAllWindows()
# Out:
# image 1/1 c:\ipynb_yolov5\temp_frame.jpg: 480x640 1 machinery, 247.9ms
# Speed: 8.0ms preprocess, 247.9ms inference, 24.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict5
#
# image 1/1 c:\ipynb_yolov5\temp_frame.jpg: 480x640 1 NO-Hardhat, 1 Person, 184.0ms
# Speed: 8.0ms preprocess, 184.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict5
#
# image 1/1 c:\ipynb_yolov5\temp_frame.jpg: 480x640 2 NO-Hardhats, 1 Person, 191.9ms
# Speed: 0.0ms preprocess, 191.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict5
#
# image 1/1 c:\ipynb_yolov5\temp_frame.jpg: 480x640 1 NO-Hardhat, 1 Person, 152.1ms
# Speed: 0.0ms preprocess, 152.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict5
#
# image 1/1 c:\ipynb_yolov5\temp_frame.jpg: 480x640 1 NO-Hardhat, 1 Person, 160.3ms
# ...
